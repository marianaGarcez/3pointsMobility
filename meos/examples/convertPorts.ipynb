# %%
import pandas as pd

# %%
df = pd.read_csv('UpdatedPub150.csv', sep=',')
df
# Out:
#        PortID                    Region Name         Main Port Name  \
# 0      7950.0  United States E Coast -- 6585                 Maurer
# 1     52235.0              Sulawesi -- 51970  Mangkasa Oil Terminal
# 2     47620.0            Madagascar -- 47350                Iharana
# 3     47360.0            Madagascar -- 47350                Andoany
# 4     47020.0              Tanzania -- 46965            Chake Chake
# ...       ...                            ...                    ...
# 3734   1560.0  Newfoundland  E Coast -- 1410             Lewisporte
# 3735   1150.0                                         Deception Bay
# 3736   1260.0                                                  Nain
# 3737   1540.0  Newfoundland  E Coast -- 1410                Botwood
# 3738   1570.0  Newfoundland  E Coast -- 1410            Twillingate
#
#      Alternate Port Name UN/LOCODE   Country Code  \
# 0                                   United States
# ...

# %%
dfcut=df[['PortID','Latitude','Longitude']]
dfcut = dfcut.astype({'PortID': 'int32'})
dfcut
# Out:
#       PortID   Latitude   Longitude
# 0       7950  40.533333  -74.250000
# 1      52235  -2.733333  121.066667
# 2      47620 -13.350000   50.000000
# 3      47360 -13.400000   48.300000
# 4      47020  -5.250000   39.766667
# ...      ...        ...         ...
# 3734    1560  49.250000  -55.050000
# 3735    1150  62.150000  -74.683333
# 3736    1260  56.550000  -61.683333
# 3737    1540  49.133333  -55.333333
# 3738    1570  49.650000  -54.766667
#
# [3739 rows x 3 columns]

# %%
dfcut.to_csv('Ports.csv')
