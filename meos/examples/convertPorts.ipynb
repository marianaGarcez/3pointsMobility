# %%
import pandas as pd

# %%
df = pd.read_csv('UpdatedPub150.csv', sep=',')
df
# Out:
#       World Port Index Number                    Region Name  \
# 0                      7950.0  United States E Coast -- 6585
# 1                     52235.0              Sulawesi -- 51970
# 2                     47620.0            Madagascar -- 47350
# 3                     47360.0            Madagascar -- 47350
# 4                     47020.0              Tanzania -- 46965
# ...                       ...                            ...
# 3734                   1560.0  Newfoundland  E Coast -- 1410
# 3735                   1150.0
# 3736                   1260.0
# 3737                   1540.0  Newfoundland  E Coast -- 1410
# 3738                   1570.0  Newfoundland  E Coast -- 1410
#
#              Main Port Name Alternate Port Name UN/LOCODE   Country Code  \
# 0                    Maurer                                United States
# 1     Mangkasa Oil Terminal                                    Indonesia
# ...

# %%
dfcut=df[['World Port Index Number','Country Code','Latitude','Longitude','Supplies - Fuel Oil','Supplies - Diesel Oil','Repairs']]
dfcut
# Out:
#       World Port Index Number   Country Code   Latitude   Longitude  \
# 0                      7950.0  United States  40.533333  -74.250000
# 1                     52235.0      Indonesia  -2.733333  121.066667
# 2                     47620.0     Madagascar -13.350000   50.000000
# 3                     47360.0     Madagascar -13.400000   48.300000
# 4                     47020.0       Tanzania  -5.250000   39.766667
# ...                       ...            ...        ...         ...
# 3734                   1560.0         Canada  49.250000  -55.050000
# 3735                   1150.0         Canada  62.150000  -74.683333
# 3736                   1260.0         Canada  56.550000  -61.683333
# 3737                   1540.0         Canada  49.133333  -55.333333
# 3738                   1570.0         Canada  49.650000  -54.766667
#
#      Supplies - Fuel Oil Supplies - Diesel Oil         Repairs
# 0                    Yes                   Yes        Moderate
# ...

# %%
dfcut.to_csv('Ports.csv')
